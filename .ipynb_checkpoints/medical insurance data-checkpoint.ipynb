# %% [markdown]
# ### medical insurance data

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.tree import DecisionTreeRegressor ,plot_tree
from sklearn.model_selection import train_test_split,GridSearchCV
from sklearn.metrics import mean_absolute_error,mean_squared_error,r2_score

# %%
df= pd.read_csv('medical_insurance.csv')
df
# Out:
#       age  gender     bmi  children smoker     region      charges
# 0      19  female  27.900         0    yes  southwest  16884.92400
# 1      18    male  33.770         1     no  southeast   1725.55230
# 2      28    male  33.000         3     no  southeast   4449.46200
# 3      33    male  22.705         0     no  northwest  21984.47061
# 4      32    male  28.880         0     no  northwest   3866.85520
# ...   ...     ...     ...       ...    ...        ...          ...
# 1333   50    male  30.970         3     no  northwest  10600.54830
# 1334   18  female  31.920         0     no  northeast   2205.98080
# 1335   18  female  36.850         0     no  southeast   1629.83350
# 1336   21  female  25.800         0     no  southwest   2007.94500
# 1337   61  female  29.070         0    yes  northwest  29141.36030
#
# [1338 rows x 7 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1338 entries, 0 to 1337
# Data columns (total 7 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       1338 non-null   int64
#  1   gender    1338 non-null   object
#  2   bmi       1338 non-null   float64
#  3   children  1338 non-null   int64
#  4   smoker    1338 non-null   object
#  5   region    1338 non-null   object
#  6   charges   1338 non-null   float64
# dtypes: float64(2), int64(2), object(3)
# memory usage: 73.3+ KB

# %%
sns.boxplot(df['age'])
# Out:
# <Axes: ylabel='age'>

# %%
sns.boxenplot(df['bmi'])
# Out:
# <Axes: ylabel='bmi'>

# %%
sns.boxenplot(df['charges'])
# Out:
# <Axes: ylabel='charges'>

# %% [markdown]
# ### eda part

# %%
df['gender'].value_counts().to_dict()
# Out:
# {'male': 676, 'female': 662}

# %%
df['gender'].replace({'male': 0, 'female': 1},inplace=True)
df
# Out:
#       age  gender     bmi  children smoker     region      charges
# 0      19       1  27.900         0    yes  southwest  16884.92400
# 1      18       0  33.770         1     no  southeast   1725.55230
# 2      28       0  33.000         3     no  southeast   4449.46200
# 3      33       0  22.705         0     no  northwest  21984.47061
# 4      32       0  28.880         0     no  northwest   3866.85520
# ...   ...     ...     ...       ...    ...        ...          ...
# 1333   50       0  30.970         3     no  northwest  10600.54830
# 1334   18       1  31.920         0     no  northeast   2205.98080
# 1335   18       1  36.850         0     no  southeast   1629.83350
# 1336   21       1  25.800         0     no  southwest   2007.94500
# 1337   61       1  29.070         0    yes  northwest  29141.36030
#
# [1338 rows x 7 columns]

# %%
df['smoker'].value_counts().to_dict()
# Out:
# {'no': 1064, 'yes': 274}

# %%
df['smoker'].replace({'no': 0, 'yes': 1},inplace=True)
df
# Out:
#       age  gender     bmi  children  smoker     region      charges
# 0      19       1  27.900         0       1  southwest  16884.92400
# 1      18       0  33.770         1       0  southeast   1725.55230
# 2      28       0  33.000         3       0  southeast   4449.46200
# 3      33       0  22.705         0       0  northwest  21984.47061
# 4      32       0  28.880         0       0  northwest   3866.85520
# ...   ...     ...     ...       ...     ...        ...          ...
# 1333   50       0  30.970         3       0  northwest  10600.54830
# 1334   18       1  31.920         0       0  northeast   2205.98080
# 1335   18       1  36.850         0       0  southeast   1629.83350
# 1336   21       1  25.800         0       0  southwest   2007.94500
# 1337   61       1  29.070         0       1  northwest  29141.36030
#
# [1338 rows x 7 columns]

# %%
df=pd.get_dummies(df,['region'],dtype=int)

# %%
df
# Out:
#       age  gender     bmi  children  smoker      charges  region_northeast  \
# 0      19       1  27.900         0       1  16884.92400                 0
# 1      18       0  33.770         1       0   1725.55230                 0
# 2      28       0  33.000         3       0   4449.46200                 0
# 3      33       0  22.705         0       0  21984.47061                 0
# 4      32       0  28.880         0       0   3866.85520                 0
# ...   ...     ...     ...       ...     ...          ...               ...
# 1333   50       0  30.970         3       0  10600.54830                 0
# 1334   18       1  31.920         0       0   2205.98080                 1
# 1335   18       1  36.850         0       0   1629.83350                 0
# 1336   21       1  25.800         0       0   2007.94500                 0
# 1337   61       1  29.070         0       1  29141.36030                 0
#
#       region_northwest  region_southeast  region_southwest
# 0                    0                 0                 1
# 1                    0                 1                 0
# 2                    0                 1                 0
# 3                    1                 0                 0
# 4                    1                 0                 0
# ...                ...               ...               ...
# 1333                 1                 0                 0
# 1334                 0                 0                 0
# 1335                 0                 1                 0
# 1336                 0                 0                 1
# 1337                 1                 0                 0
#
# [1338 rows x 10 columns]

# %% [markdown]
# ### model training

# %%
x= df.drop(['charges'],axis=1)
y=df['charges']

# %%
x_train,x_test,y_train,y_test= train_test_split(x,y,test_size=0.2,random_state=42)
x_train
# Out:
#       age  gender     bmi  children  smoker  region_northeast  \
# 560    46       1  19.950         2       0                 0
# 1285   47       1  24.320         0       0                 1
# 1142   52       1  24.860         0       0                 0
# 969    39       1  34.320         5       0                 0
# 486    54       1  21.470         3       0                 0
# ...   ...     ...     ...       ...     ...               ...
# 1095   18       1  31.350         4       0                 1
# 1130   39       1  23.870         5       0                 0
# 1294   58       0  25.175         0       0                 1
# 860    37       1  47.600         2       1                 0
# 1126   55       0  29.900         0       0                 0
#
#       region_northwest  region_southeast  region_southwest
# 560                  1                 0                 0
# 1285                 0                 0                 0
# 1142                 0                 1                 0
# 969                  0                 1                 0
# 486                  1                 0                 0
# ...                ...               ...               ...
# 1095                 0                 0                 0
# 1130                 0                 1                 0
# 1294                 0                 0                 0
# 860                  0                 0                 1
# 1126                 0                 0                 1
#
# [1070 rows x 9 columns]

# %%
dt_reg=DecisionTreeRegressor(random_state=1)
dt_reg.fit(x_train,y_train)
# Out:
# DecisionTreeRegressor(random_state=1)

# %%
dt_reg.feature_importances_
# Out:
# array([0.13390947, 0.01267742, 0.20804217, 0.01589946, 0.60952896,
#        0.00677998, 0.00586665, 0.0052947 , 0.00200119])

# %% [markdown]
# ### model evaluation

# %%
y_predict_train=dt_reg.predict(x_train)

# %% [markdown]
# ### Trainng data set accuracy

# %%
mse=mean_absolute_error(y_train,y_predict_train)
print('mean_absolute_error',mse)
rmse= np.sqrt(mse)
print('rmse',rmse)
r2score=r2_score(y_train,y_predict_train)
print('r2score',r2score)
# Out:
# mean_absolute_error 29.572515327102803
# rmse 5.438061725201618
# r2score 0.9983078124756305

# %% [markdown]
# ### testing data set accuracy

# %%
y_predict_test=dt_reg.predict(x_test)

# %%
mse=mean_absolute_error(y_test,y_predict_test)
print('mean_absolute_error',mse)
rmse= np.sqrt(mse)
print('rmse',rmse)
r2score=r2_score(y_test,y_predict_test)
print('r2score',r2score)
# Out:
# mean_absolute_error 3333.955739238806
# rmse 57.7404168606255
# r2score 0.6797698610471736

# %%
plt.figure(figsize=(100,80))
plot_tree(dt_reg)
plt.savefig('tree.jpg')
